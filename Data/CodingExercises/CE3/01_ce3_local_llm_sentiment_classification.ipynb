# %% [markdown]
# # Coding Exercise 3: Local LLM Sentiment Classification
#
# In this exercise, we'll use a small LLM _running on our own machine_ (well, on a Google Colab virtual machine...) to automatically classify customer reviews as positive, negative, or neutral.
#
# This is a practical example of how businesses use AI today — instead of a human reading thousands of reviews, an LLM can do it in seconds.
#
# It follows from **Episode 7**, where we looked at how LLMs work and the wealth of possible use cases. It also illustrates an area where LLMs can perform as well, if not better than traditional NLP-based sentiment analysis.
#
# ## What we'll do:
# 1. **Fetch reviews** from a URL using Python's `requests` library (simulating pulling data from an API)
# 2. **Load a small LLM** called Qwen2.5-0.5B-Instruct onto our machine
# 3. **Classify each review** by giving the model a carefully worded prompt
# 4. **Review the results** and discuss what worked and what didn't
#
# **Note: From the Runtime menu above, select "Change runtime type" and then select "T4 GPU" for the hardware accelerator. This will run the model significantly faster than on the CPU runtime.**
#
# ## Why a local model?
# Services like ChatGPT and Claude run on remote servers — you send your data to them over the internet. A **local model** runs right here on this computer. This matters when:
# - You're working with **sensitive data** (medical records, financial info) that can't leave your system
# - You want to avoid **API costs** (cloud AI services charge per request)
# - You need to work **offline** or with very low latency
#
# The trade-off: local models are typically much smaller and less capable than cloud models.
#
# ## Learning Objectives
#
# By the end of this exercise, you should understand:
# 1. How the `requests` Python library can be used to retrieve data from the web
# 2. How to download a local model from Hugging Face
# 3. How to load that model into PyTorch, along with its tokenizer
# 4. How to write a classifier function we can use to classify each review
# 5. How to clean and santise the model output
# 6. How to summarise and sanity check results
#
# The aim here is to extend what we've learned about building and training models into actually using them to do stuff.

# %% [markdown]
# ---
# ## 1: Install dependencies
#
# We need two Python libraries:
# - **`transformers`** — Hugging Face's library for downloading and running AI models
# - **`torch`** (PyTorch) — the underlying framework that does the actual computation
# - **`requests`** — a simple library for fetching data from URLs (comes pre-installed, but we include it for clarity)
#
# The `-q` flag means "quiet" — it suppresses most of the installation output to keep things tidy.

# %%
# !pip install -q transformers torch requests

# %% [markdown]
# ---
# ## 2: Fetch customer reviews
#
# In a real-world scenario, reviews might come from:
# - A company's database or API
# - A web scraping pipeline
# - A CSV file exported from a survey tool
#
# Here we define them inline for simplicity, but the commented-out code at the top shows how you'd fetch them from a hosted JSON file using `requests.get()`.
#
# Each review is a Python **dictionary** with an `id` and `text` field — a common format for structured data.

# %%
import requests
import json

# ------------------------------------------------------------------
# OPTION A: Fetch from a real URL (uncomment these lines to use)
# ------------------------------------------------------------------
url = "https://raw.githubusercontent.com/uoy-research/tfds-course-ai/refs/heads/main/Data/CodingExercises/CE3/02_ce3_restaurant_reviews.json"
response = requests.get(url)      # Send an HTTP GET request to the URL
reviews = response.json()          # Parse the JSON response into a Python list

# ------------------------------------------------------------------
# OPTION B: Define reviews inline for testing
# ------------------------------------------------------------------
# reviews = [
#     {"id": 1, "text": "Absolutely love this product! Best purchase I've made all year."},
#     {"id": 2, "text": "Terrible quality. Broke after two days. Complete waste of money."},
#     {"id": 3, "text": "It's okay. Does what it's supposed to do, nothing special."},
#     {"id": 4, "text": "Shipping was fast and the item exceeded my expectations!"},
#     {"id": 5, "text": "Not worth the price. The description was misleading."},
#     {"id": 6, "text": "Decent product for the price point. Would consider buying again."},
#     {"id": 7, "text": "DO NOT BUY. Customer service was rude and unhelpful."},
#     {"id": 8, "text": "Works as advertised. Arrived on time."},
#     {"id": 9, "text": "This changed my life! I've already recommended it to all my friends."},
#     {"id": 10, "text": "Meh. It's fine I guess. Not great, not terrible."}
# ]

# Print what we've got
print(f"Loaded {len(reviews)} reviews\n")
for r in reviews:
    print(f"  [{r['id']:>2}] {r['text']}")
# Out:
# Loaded 250 reviews
#
#   [ 1] I've tried to recreate their carbonara at home and I simply cannot. There's some kind of magic happening in that kitchen.
#   [ 2] They make their own pasta in-house and you can watch them doing it. The tagliatelle was sublime.
#   [ 3] The salad was fresh enough and reasonably sized. Fairly priced too. Just not very exciting.
#   [ 4] I asked for no onions due to an allergy and my dish arrived loaded with onions. Dangerous.
#   [ 5] The vegan options consisted of a side salad. In 2024. Really.
#   [ 6] The panini was so tightly pressed it was basically a cracker with some cheese inside.
#   [ 7] The chef came out to check on our table personally. That kind of attention to detail is rare.
#   [ 8] Decent enough for a quick lunch. Standard fare at standard prices.
#   [ 9] We come here occasionally when everywhere else is full. It does what it needs to do.
#   [10] Sticky tables, dirty cutlery, and a general feeling that hygiene isn't a priority here.
#   [11] The staff went above and beyond to accommodate our dietary needs. Will definitely be back.
#   [12] A perfect neighbourhood restaurant. Reliable, welcoming, and the food always delivers.
#   [13] The tasting menu was a culinary journey. Every course was a surprise and a delight.
#   [14] The katsu curry was crispy, saucy, and deeply comforting. My new favourite comfort food.
#   [15] We split the bill evenly because everything was roughly the same quality — middling.
#   [16] I've been to every burger joint in the city and this one wins. It's not even close.
#   [17] The pizza base was like cardboard. Thin and crispy is one thing, dry and flavourless is another.
#   [18] The cocktail menu alone is worth the visit, but the tapas are equally impressive.
#   [19] The waiter was incredibly rude when we asked about allergens. Won't be returning.
#   [20] The pasta was so overcooked it was basically mush. My five-year-old could do better.
#   [21] The service was neither fast nor slow. The food was neither hot nor cold. Just very middle.
#   [22] The vegetarian options are excellent but the meat dishes are weirdly bland.
#   [23] The gnocchi was light as air. I don't know how they do it but it was extraordinary.
#   [24] The chocolate fondant was the best I've ever tasted. Perfectly gooey in the middle.
#   [25] The sauce on the pasta tasted like it came straight out of a jar. Dolmio does it better.
#   [26] Average place with average food at average prices. The very definition of three stars.
#   [27] The falafel wrap was crunchy, fresh, and the tahini sauce was incredible.
#   [28] The pulled pork sandwich was smoky, tender, and piled high. Absolute beast of a meal.
#   [29] Disappointing. The reviews online must be fake because the food was absolutely nothing special.
#   [30] The food was what it was. Not worth complaining about but not worth praising either.
#   [31] Found a hair in my soup. Lost my appetite for the rest of the meal.
#   [32] The charcuterie board had meats I'd never tried before and every single one was delicious.
#   [33] Lovely little café with homemade cakes that taste like your grandmother made them.
#   [34] The chocolate cake was so dry I needed an entire glass of water to get through one slice.
#   [250] We pointed out a fly in the restaurant and were told 'it's summer, what do you expect?'.

# %% [markdown]
# ---
# ## 3: Load the language model
#
# We're using **Qwen2.5-0.5B-Instruct** — a model with 0.5 billion parameters created by Alibaba's Qwen team.
#
# To put that in context:
# - **GPT-4** is estimated to have over **1 trillion** parameters
# - **Qwen2.5-0.5B** has **500 million** — roughly 2,000x smaller
#
# Despite being tiny by modern standards, it's been specifically **instruction-tuned**, meaning it was trained to follow instructions (like "classify this review") rather than just predict the next word.
#
# ### What's happening in the code below:
#
# 1. **`AutoTokenizer`** loads the model's **tokenizer** — this converts human-readable text into numbers (tokens) that the model can process. Every model has its own specific tokenizer.
#
# 2. **`AutoModelForCausalLM`** loads the actual model weights — this is the "brain" of the model, containing all 500 million learned parameters.
#
# 3. **`torch_dtype=torch.float32`** tells PyTorch what numerical precision to use. `float32` is the standard — each parameter is stored as a 32-bit floating point number.
#
# 4. **Device selection** — we check if a GPU is available (faster) and fall back to CPU if not. For a model this small, CPU works fine.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "Qwen/Qwen2.5-0.5B-Instruct"

# --- Load the tokenizer ---
# The tokenizer converts text to tokens (numbers) and back again.
# For example: "I love it" might become [40, 3021, 433]
print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(model_name)

# --- Load the model ---
# This downloads ~1GB of model weights the first time.
# Subsequent runs use the cached version.
print("Loading model (this may take a minute the first time)...")
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float32  # Standard precision; works on all hardware
)

# --- Choose the best available device ---
if torch.cuda.is_available():
    device = "cuda"   # NVIDIA GPU — much faster
    print("Using GPU")
else:
    device = "cpu"     # Standard processor — slower but always available
    print("Using CPU (plenty fast for a 0.5B model)")

# Move the model to our chosen device
model = model.to(device)

# Print a summary
total_params = sum(p.numel() for p in model.parameters())
print(f"\nModel loaded on {device}!")
print(f"Total parameters: {total_params:,} ({total_params / 1e9:.2f} billion)")
# Out:
# Loading tokenizer...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading model (this may take a minute the first time)...
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Using GPU
#
# Model loaded on cuda!
# Total parameters: 494,032,768 (0.49 billion)

# %% [markdown]
# ---
# ## 4: Build the classification function
#
# This is the core of the exercise. We need to:
# 1. **Construct a prompt** that tells the model what we want
# 2. **Format it** using the model's expected chat template
# 3. **Tokenize** the prompt (convert text → numbers)
# 4. **Generate** a response from the model
# 5. **Decode** the response (convert numbers → text)
# 6. **Parse** the result to extract a clean label
#
# ### About the prompt design:
#
# We use two messages — a **system message** and a **user message**:
#
# - The **system message** sets the model's role and behaviour: *"You are a sentiment classifier. Reply with exactly one word."* This is like giving an employee their job description before handing them a task.
#
# - The **user message** contains the actual review to classify.
#
# Separating instructions from data is a prompting best practice — it helps the model understand what's an instruction vs. what's the content to process.
#
# ### About `temperature`:
#
# Temperature controls randomness in the model's output:
# - **0.0** = always pick the most likely next word (deterministic)
# - **1.0** = sample proportionally from all possibilities (creative/varied)
# - **0.1** (our setting) = almost deterministic, with just a tiny bit of variation
#
# For classification, we want consistency, so we keep temperature very low.

# %%
def classify_review(review_text, model, tokenizer, device):
    """
    Classify a single review as POSITIVE, NEGATIVE, or NEUTRAL.

    Args:
        review_text: The review string to classify
        model: The loaded language model
        tokenizer: The model's tokenizer
        device: 'cuda' for GPU or 'cpu'

    Returns:
        A tuple of (normalised_label, raw_model_output)
    """

    # --- 1. Construct the prompt as a conversation ---
    messages = [
        {
            "role": "system",
            "content": (
                "You are a sentiment classifier. "
                "You reply with exactly one word: POSITIVE, NEGATIVE, or NEUTRAL. "
                "No explanation."
            )
        },
        {
            "role": "user",
            "content": f"Classify this review:\n\"{review_text}\""
        }
    ]

    # --- 2. Apply the chat template ---
    # Each model expects its prompt formatted a specific way.
    # The chat template converts our messages list into the exact format
    # the model was trained on (with special tokens like <|im_start|>).
    # add_generation_prompt=True adds the marker that tells the model
    # "now it's your turn to respond".
    input_text = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )

    # --- 3. Tokenize ---
    # Convert the formatted text into token IDs (numbers) and move
    # them to the same device (CPU/GPU) as the model.
    # return_tensors="pt" means "return PyTorch tensors"
    inputs = tokenizer(input_text, return_tensors="pt").to(device)

    # --- 4. Generate a response ---
    # torch.no_grad() tells PyTorch we're only doing inference (not training),
    # so it doesn't need to track gradients — this saves memory and speeds things up.
    with torch.no_grad():
        outputs = model.generate(
            **inputs,               # The tokenized prompt
            max_new_tokens=5,       # Only generate up to 5 new tokens (we just need one word)
            temperature=0.1,        # Very low randomness — we want a consistent answer
            do_sample=True,         # Enable sampling (required when temperature > 0)
            pad_token_id=tokenizer.eos_token_id  # Technical detail: tells model what "padding" looks like
        )

    # --- 5. Decode the response ---
    # The model's output includes our entire input PLUS the new tokens.
    # We slice off just the new tokens using the length of our input.
    new_tokens = outputs[0][inputs['input_ids'].shape[1]:]  # Everything after our prompt
    generated = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()

    # --- 6. Parse and normalise the label ---
    # The model might say "POSITIVE" or "Positive" or "positive." etc.
    # We extract the first word and check if it matches our categories.
    first_word = generated.upper().split()[0] if generated else ""

    if "POSITIVE" in first_word or "POS" in first_word:
        return "POSITIVE", generated
    elif "NEGATIVE" in first_word or "NEG" in first_word:
        return "NEGATIVE", generated
    elif "NEUTRAL" in first_word or "NEU" in first_word:
        return "NEUTRAL", generated
    else:
        return "UNKNOWN", generated  # Model didn't give us a clean answer

# %% [markdown]
# ---
# ## 5: Run the classifier on all reviews
#
# Now we loop through each review and classify it. We also time the process to see how fast our small model is.

# %%
import time

print("Classifying reviews...\n")
print(f"{'ID':>3} | {'Label':<10} | {'Raw Output':<15} | Review")
print("-" * 80)

results = []
start_time = time.time()

for review in reviews:
    label, raw = classify_review(review["text"], model, tokenizer, device)
    results.append({
        "id": review["id"],
        "text": review["text"],
        "label": label,
        "raw": raw
    })
    print(f"{review['id']:>3} | {label:<10} | {raw:<15} | {review['text'][:45]}")

elapsed = time.time() - start_time
print(f"\nDone! Classified {len(reviews)} reviews in {elapsed:.1f}s")
print(f"Average: {elapsed/len(reviews):.2f}s per review")
# Out:
# Classifying reviews...
#
#  ID | Label      | Raw Output      | Review
# --------------------------------------------------------------------------------
#   1 | NEGATIVE   | NEGATIVE        | I've tried to recreate their carbonara at hom
#   2 | POSITIVE   | POSITIVE        | They make their own pasta in-house and you ca
#   3 | NEGATIVE   | NEGATIVE        | The salad was fresh enough and reasonably siz
#   4 | NEGATIVE   | NEGATIVE        | I asked for no onions due to an allergy and m
#   5 | NEGATIVE   | NEGATIVE        | The vegan options consisted of a side salad.
#   6 | NEGATIVE   | NEGATIVE        | The panini was so tightly pressed it was basi
#   7 | POSITIVE   | POSITIVE        | The chef came out to check on our table perso
#   8 | NEUTRAL    | NEUTRAL         | Decent enough for a quick lunch. Standard far
#   9 | NEUTRAL    | NEUTRAL         | We come here occasionally when everywhere els
#  10 | NEGATIVE   | NEGATIVE        | Sticky tables, dirty cutlery, and a general f
#  11 | POSITIVE   | POSITIVE        | The staff went above and beyond to accommodat
#  12 | POSITIVE   | POSITIVE        | A perfect neighbourhood restaurant. Reliable,
#  13 | POSITIVE   | POSITIVE        | The tasting menu was a culinary journey. Ever
#  14 | POSITIVE   | POSITIVE        | The katsu curry was crispy, saucy, and deeply
#  15 | NEUTRAL    | NEUTRAL         | We split the bill evenly because everything w
#  16 | POSITIVE   | POSITIVE        | I've been to every burger joint in the city a
#  17 | NEGATIVE   | NEGATIVE        | The pizza base was like cardboard. Thin and c
#  18 | NEUTRAL    | NEUTRAL         | The cocktail menu alone is worth the visit, b
#  19 | NEGATIVE   | NEGATIVE        | The waiter was incredibly rude when we asked
#  20 | NEGATIVE   | NEGATIVE        | The pasta was so overcooked it was basically
#  21 | NEUTRAL    | NEUTRAL         | The service was neither fast nor slow. The fo
#  22 | NEGATIVE   | NEGATIVE        | The vegetarian options are excellent but the
#  23 | POSITIVE   | POSITIVE        | The gnocchi was light as air. I don't know ho
#  24 | POSITIVE   | POSITIVE        | The chocolate fondant was the best I've ever
#  25 | NEUTRAL    | NEUTRAL         | The sauce on the pasta tasted like it came st
#  26 | NEGATIVE   | NEGATIVE        | Average place with average food at average pr
#  27 | POSITIVE   | POSITIVE        | The falafel wrap was crunchy, fresh, and the
#  28 | POSITIVE   | POSITIVE        | The pulled pork sandwich was smoky, tender, a
#  29 | NEGATIVE   | NEGATIVE        | Disappointing. The reviews online must be fak
#  30 | NEUTRAL    | NEUTRAL         | The food was what it was. Not worth complaini
#  31 | NEGATIVE   | NEGATIVE        | Found a hair in my soup. Lost my appetite for
#  32 | POSITIVE   | POSITIVE        | The charcuterie board had meats I'd never tri
#  33 | POSITIVE   | POSITIVE        | Lovely little café with homemade cakes that t
#  34 | NEGATIVE   | NEGATIVE        | The chocolate cake was so dry I needed an ent
#  35 | NEGATIVE   | NEGATIVE        | Quality has gone downhill since they changed
#  36 | NEUTRAL    | NEUTRAL         | A reliable option. Never amazing but never te
#  37 | POSITIVE   | POSITIVE        | They do a bottomless brunch that is genuinely
#  38 | POSITIVE   | POSITIVE        | The brisket had been smoked for 14 hours and
#  39 | POSITIVE   | POSITIVE        | The seafood platter was spectacular — fresh o
#  40 | NEGATIVE   | NEGATIVE        | The menu is small but everything on it is com
#  41 | NEGATIVE   | NEGATIVE        | They ran out of three things I tried to order
#  42 | POSITIVE   | POSITIVE        | The service was warm and attentive without be
#  43 | POSITIVE   | POSITIVE        | This restaurant single-handedly got me into I
#  44 | POSITIVE   | POSITIVE        | Brilliant place for a date night. Intimate, r
#  45 | NEGATIVE   | NEGATIVE        | The lunch menu is brilliant value. The dinner
#  46 | POSITIVE   | POSITIVE        | Honestly the best Thai food outside of Thaila
#  47 | NEGATIVE   | NEGATIVE        | They refused to split the bill for our group
#  48 | NEGATIVE   | NEGATIVE        | The restaurant was freezing cold and they sai
#  49 | POSITIVE   | POSITIVE        | The sommelier recommended a wine I never woul
#  50 | NEUTRAL    | NEUTRAL         | The dumplings were acceptable. Store-bought q
#  51 | NEGATIVE   | NEGATIVE        | Asked for my steak medium rare and got a piec
#  52 | NEGATIVE   | NEGATIVE        | We were rushed through our meal because they
#  53 | NEGATIVE   | NEGATIVE        | The calamari was rubbery and the batter was s
#  54 | NEGATIVE   | NEGATIVE        | We asked for the bill three times before anyo
#  55 | POSITIVE   | POSITIVE        | This little gem is the best-kept secret in to
#  56 | POSITIVE   | POSITIVE        | The paella was loaded with seafood and the ri
#  57 | NEGATIVE   | NEGATIVE        | The regular menu is solid but the specials ar
#  58 | POSITIVE   | POSITIVE        | We come here every Sunday and it has become o
#  59 | NEUTRAL    | NEUTRAL         | Nothing exciting on the menu but nothing offe
#  60 | POSITIVE   | POSITIVE        | Took my mum here for her birthday and she lov
#  61 | POSITIVE   | POSITIVE        | Superb Korean BBQ. The banchan alone would be
#  62 | NEGATIVE   | NEGATIVE        | The garlic bread was burnt to a crisp. When I
#  63 | NEGATIVE   | NEGATIVE        | The wine list was overpriced — the cheapest b
#  64 | NEGATIVE   | NEGATIVE        | The bread basket cost £5 extra and it was thr
#  65 | NEGATIVE   | NEGATIVE        | Excellent location and nice outdoor seating b
#  66 | POSITIVE   | POSITIVE        | What a find! Tucked away on a side street but
#  67 | NEUTRAL    | NEUTRAL         | Standard curry house. Decent naan, acceptable
#  68 | POSITIVE   | POSITIVE        | My four-year-old declared it 'the best restau
#  69 | NEUTRAL    | NEUTRAL         | Went for a work lunch. It was food. We ate it
#  70 | POSITIVE   | POSITIVE        | Incredible sushi! The fish was so fresh it pr
#  71 | NEGATIVE   | NEGATIVE        | We waited 20 minutes just to get menus. Then
#  72 | NEGATIVE   | NEGATIVE        | The fried chicken was greasy and the coating
#  73 | POSITIVE   | POSITIVE        | Perfectly cromulent restaurant. The food was
#  74 | NEGATIVE   | NEGATIVE        | Noisy, cramped, and the food was mediocre at
#  75 | NEGATIVE   | NEGATIVE        | The online photos look nothing like the actua
#  76 | POSITIVE   | POSITIVE        | The bread and butter they bring to start is b
#  77 | POSITIVE   | POSITIVE        | The naan bread was soft and pillowy, straight
#  78 | NEGATIVE   | NEGATIVE        | The breakfast was substantial and reasonably
#  79 | NEGATIVE   | NEGATIVE        | The milkshake tasted like flavoured milk. No
#  80 | NEUTRAL    | NEUTRAL         | The banana bread is so popular they sell out
#  81 | POSITIVE   | POSITIVE        | The pad thai was exactly like what I had in B
#  82 | POSITIVE   | POSITIVE        | We sat outside on the terrace and the whole e
#  83 | NEGATIVE   | NEGATIVE        | The tiramisu was dry and tasted like it had b
#  84 | POSITIVE   | POSITIVE        | Lovely atmosphere, great wine list, and the r
#  85 | NEUTRAL    | NEUTRAL         | It's the kind of place you forget you've been
#  86 | NEUTRAL    | NEUTRAL         | Amazing cocktails, below-average food. Come f
#  87 | POSITIVE   | POSITIVE        | It's not cheap but it's the kind of meal you
#  88 | POSITIVE   | POSITIVE        | Their breakfast burrito is the reason I get u
#  89 | POSITIVE   | POSITIVE        | Best pizza I've ever had. The crust was perfe
#  90 | NEUTRAL    | NEUTRAL         | Clean, efficient, unremarkable. It's a perfec
#  91 | NEGATIVE   | NEGATIVE        | They wouldn't honour their own voucher becaus
#  92 | NEGATIVE   | NEGATIVE        | I've eaten here maybe five times and I couldn
#  93 | POSITIVE   | POSITIVE        | The tiramisu here is legendary and now I unde
#  94 | NEGATIVE   | NEGATIVE        | Waited 45 minutes for our food and when it ar
#  95 | NEUTRAL    | NEUTRAL         | It's a solid 3 out of 5. You won't be disappo
#  96 | POSITIVE   | POSITIVE        | We took some clients here and it made us look
#  97 | NEUTRAL    | NEUTRAL         | I'm coeliac and they had an entire separate g
#  98 | NEGATIVE   | NEGATIVE        | The cocktails were weak and tasted like they'
#  99 | NEUTRAL    | NEUTRAL         | Neither delighted nor angered by this dining
# 100 | NEGATIVE   | NEGATIVE        | Great starters, terrible mains. Very inconsis
# 101 | NEUTRAL    | NEUTRAL         | The dessert was clearly bought in from a supe
# 102 | NEGATIVE   | NEGATIVE        | Booked online, got a confirmation, arrived an
# 103 | POSITIVE   | POSITIVE        | Functional. That's the word I'd use. It funct
# 104 | NEUTRAL    | NEUTRAL         | It's fine for a quick bite. I wouldn't plan a
# 105 | NEGATIVE   | NEGATIVE        | Love the location, love the vibe, but the foo
# 106 | POSITIVE   | POSITIVE        | The wood-fired oven makes all the difference.
# 107 | NEGATIVE   | NEGATIVE        | The steak was mostly fat and gristle. For £35
# 108 | NEGATIVE   | NEGATIVE        | The spaghetti bolognese tasted like school di
# 109 | NEGATIVE   | NEGATIVE        | The portion sizes are a joke for the prices t
# 110 | NEUTRAL    | NEUTRAL         | We ordered every dessert on the menu. Not a s
# 111 | NEUTRAL    | NEUTRAL         | The lasagne was okay. A bit heavy on the béch
# 112 | NEGATIVE   | NEGATIVE        | The nachos were stale tortilla chips with som
# 113 | POSITIVE   | POSITIVE        | I'm from Naples and this is the closest I've
# 114 | NEUTRAL    | NEUTRAL         | I give it a solid 'meh'. Not actively bad, ju
# 115 | NEUTRAL    | NEUTRAL         | Looked great on Instagram. Tasted like any ot
# 116 | NEGATIVE   | NEGATIVE        | The starter was one of the best things I've e
# 117 | NEGATIVE   | NEGATIVE        | I want to love this place because the staff a
# 118 | NEUTRAL    | NEUTRAL         | The risotto was crunchy. Risotto. Crunchy. En
# 119 | POSITIVE   | POSITIVE        | Absolutely fantastic. The duck confit was cri
# 120 | NEGATIVE   | NEGATIVE        | The lamb was tough and chewy. It clearly hadn
# 121 | NEGATIVE   | NEGATIVE        | The burger was dry and flavourless. The bun w
# 122 | NEGATIVE   | NEGATIVE        | The food was amazing but the service was so b
# 123 | NEUTRAL    | NEUTRAL         | The food arrived quickly and tasted as expect
# 124 | NEUTRAL    | NEUTRAL         | The food was okay. The service was okay. Ever
# 125 | NEGATIVE   | NEGATIVE        | The toilet was disgusting. If that's the stat
# 126 | NEUTRAL    | NEUTRAL         | The fried chicken here has a secret spice ble
# 127 | NEGATIVE   | NEGATIVE        | An inoffensive dining experience. Everything
# 128 | NEGATIVE   | NEGATIVE        | The portions were fair, the taste was adequat
# 129 | NEUTRAL    | NEUTRAL         | The pasta was cooked properly and the sauce w
# 130 | NEGATIVE   | NEGATIVE        | The table wobbled so badly my drink spilled.
# 131 | NEGATIVE   | NEGATIVE        | Reserved a table for 7pm, arrived on time, an
# 132 | NEGATIVE   | NEGATIVE        | The pad thai was swimming in oil and tasted o
# 133 | POSITIVE   | POSITIVE        | The eggs florentine were so good I ordered a
# 134 | NEGATIVE   | NEGATIVE        | Perfect for a casual meal but don't come here
# 135 | NEUTRAL    | NEUTRAL         | Neither impressed nor disappointed. It exists
# 136 | POSITIVE   | POSITIVE        | Every single side dish was as thoughtfully pr
# 137 | NEUTRAL    | NEUTRAL         | The soup was warming and filling. Not the bes
# 138 | NEGATIVE   | NEGATIVE        | The chicken was raw in the middle. Absolutely
# 139 | NEGATIVE   | NEGATIVE        | The waiter spilled red wine on my white shirt
# 140 | POSITIVE   | POSITIVE        | The sandwich was exactly what you'd expect. H
# 141 | NEGATIVE   | NEGATIVE        | I found plastic in my salad. When I told the
# 142 | POSITIVE   | POSITIVE        | The taco al pastor was authentic and packed w
# 143 | POSITIVE   | POSITIVE        | Quick service, friendly staff, and the burger
# 144 | NEGATIVE   | NEGATIVE        | The place was filthy. Crumbs on the seats, st
# 145 | NEGATIVE   | NEGATIVE        | Overpriced and underwhelming. Paid £60 for wh
# 146 | POSITIVE   | POSITIVE        | The matcha latte was the best I've had in thi
# 147 | NEGATIVE   | NEGATIVE        | The pizza was great but the pasta was awful.
# 148 | NEUTRAL    | NEUTRAL         | It was fine. Nothing wrong with it but nothin
# 149 | NEUTRAL    | NEUTRAL         | This place has completely ruined other Italia
# 150 | POSITIVE   | POSITIVE        | The scones with clotted cream and jam were pe
# 151 | NEUTRAL    | NEUTRAL         | The rice was cooked well and the curry was re
# 152 | NEGATIVE   | NEGATIVE        | They charged us for items we didn't order and
# 153 | POSITIVE   | POSITIVE        | We had the chef's special and it was a revela
# 154 | NEGATIVE   | NEGATIVE        | The bill included a mandatory tip despite the
# 155 | NEGATIVE   | NEGATIVE        | The curry was bland and watery. No spice, no
# 156 | NEGATIVE   | NEGATIVE        | The breakfast was lukewarm and clearly been s
# 157 | NEUTRAL    | NEUTRAL         | First visit was a 5/5, second visit was a 2/5
# 158 | NEGATIVE   | NEGATIVE        | The soup of the day tasted like hot water wit
# 159 | POSITIVE   | POSITIVE        | Fresh, vibrant, flavourful — this salad bar h
# 160 | NEGATIVE   | NEGATIVE        | The ramen broth tasted like it had been made
# 161 | POSITIVE   | POSITIVE        | The dim sum here is authentic and delicious.
# 162 | POSITIVE   | POSITIVE        | What impressed me most was how every dish arr
# 163 | POSITIVE   | POSITIVE        | I'm obsessed with their avocado toast. I know
# 164 | POSITIVE   | POSITIVE        | The view from the rooftop terrace paired with
# 165 | POSITIVE   | POSITIVE        | This tiny hole-in-the-wall serves the best du
# 166 | POSITIVE   | POSITIVE        | Brought a group of 12 for a work dinner and t
# 167 | POSITIVE   | POSITIVE        | The mango sticky rice dessert transported me
# 168 | NEGATIVE   | NEGATIVE        | The chips were clearly frozen ones from a bag
# 169 | NEGATIVE   | NEGATIVE        | They added a 15% service charge automatically
# 170 | POSITIVE   | POSITIVE        | The wrap was filling and reasonably tasty. Wo
# 171 | NEGATIVE   | NEGATIVE        | The omelette was fluffy and filled. Good port
# 172 | POSITIVE   | POSITIVE        | The laksa was rich, spicy, and deeply satisfy
# 173 | NEGATIVE   | NEGATIVE        | Food was good but they sat us next to a table
# 174 | NEUTRAL    | NEUTRAL         | It's a convenient spot with reasonable prices
# 175 | POSITIVE   | POSITIVE        | Amazing vegan menu that doesn't feel like an
# 176 | POSITIVE   | POSITIVE        | The croissants are flaky and buttery — clearl
# 177 | NEGATIVE   | NEGATIVE        | The gyoza were clearly microwaved. The bottom
# 178 | NEUTRAL    | NEUTRAL         | The coffee was standard. The cake was standar
# 179 | POSITIVE   | POSITIVE        | We brought our kids and they were so accommod
# 180 | POSITIVE   | POSITIVE        | They remembered our names from our last visit
# 181 | NEGATIVE   | NEGATIVE        | We made a booking for a birthday and asked fo
# 182 | POSITIVE   | POSITIVE        | The granola bowl was fresh, crunchy, and not
# 183 | NEGATIVE   | NEGATIVE        | They don't take reservations and we queued fo
# 184 | NEGATIVE   | NEGATIVE        | I specifically asked for dairy-free and the s
# 185 | POSITIVE   | POSITIVE        | The moules frites were perfectly cooked — plu
# 186 | NEGATIVE   | NEGATIVE        | The air conditioning was broken in the middle
# 187 | POSITIVE   | POSITIVE        | I'm a regular and have never had a bad meal h
# 188 | POSITIVE   | POSITIVE        | We've tried dozens of sushi restaurants and k
# 189 | POSITIVE   | POSITIVE        | Went for a quick lunch and stayed for three h
# 190 | NEGATIVE   | NEGATIVE        | My gluten-free meal arrived on a regular bun.
# 191 | NEGATIVE   | NEGATIVE        | The kids' menu was just frozen nuggets and ch
# 192 | NEUTRAL    | NEUTRAL         | Came here because it was close to the office.
# 193 | POSITIVE   | POSITIVE        | Portions are generous and the prices are very
# 194 | POSITIVE   | POSITIVE        | The ceviche was bright, zingy, and perfectly
# 195 | NEGATIVE   | NEGATIVE        | Beautiful decor and lovely atmosphere, but th
# 196 | POSITIVE   | POSITIVE        | I love that they source everything locally. Y
# 197 | POSITIVE   | POSITIVE        | My steak arrived still sizzling and it was co
# 198 | POSITIVE   | POSITIVE        | My vegetarian friend said this was the first
# 199 | POSITIVE   | POSITIVE        | The french onion soup had a thick layer of me
# 200 | NEGATIVE   | NEGATIVE        | The desserts were incredible but we had to wa
# 201 | NEGATIVE   | NEGATIVE        | Great concept, poor execution. The idea behin
# 202 | POSITIVE   | POSITIVE        | They gave us a complimentary amuse-bouche tha
# 203 | NEUTRAL    | NEUTRAL         | Perfectly acceptable for a Tuesday night dinn
# 204 | NEUTRAL    | NEUTRAL         | Loved the food, hated the noise level. Would
# 205 | POSITIVE   | POSITIVE        | I ordered the fish and chips on a whim and it
# 206 | NEUTRAL    | NEUTRAL         | A three-star restaurant in every possible sen
# 207 | POSITIVE   | POSITIVE        | The truffle pasta was aromatic and indulgent.
# 208 | NEGATIVE   | NEGATIVE        | Service was the best I've ever experienced bu
# 209 | NEUTRAL    | NEUTRAL         | Average pizza. Not bad, not great. Does the j
# 210 | POSITIVE   | POSITIVE        | The butter chicken was rich and creamy withou
# 211 | NEGATIVE   | NEGATIVE        | Clean restaurant, polite staff, bland food. T
# 212 | POSITIVE   | POSITIVE        | The chicken was seasoned fine and cooked thro
# 213 | POSITIVE   | POSITIVE        | We came here for our anniversary and it did n
# 214 | NEUTRAL    | NEUTRAL         | The pizza was round, had toppings, and was wa
# 215 | POSITIVE   | POSITIVE        | A truly special place. The kind of restaurant
# 216 | NEGATIVE   | NEGATIVE        | The espresso was bitter and burnt. For a plac
# 217 | NEGATIVE   | NEGATIVE        | The music was so loud we had to shout to have
# 218 | POSITIVE   | POSITIVE        | The cheese board was a work of art. Beautiful
# 219 | NEGATIVE   | NEGATIVE        | They got our order wrong twice and didn't eve
# 220 | NEGATIVE   | NEGATIVE        | The chef clearly has talent but the portions
# 221 | NEUTRAL    | NEUTRAL         | Pretty standard pub food. The fish and chips
# 222 | NEGATIVE   | NEGATIVE        | Our food arrived at completely different time
# 223 | NEUTRAL    | NEUTRAL         | Good for what it is. It's a chain restaurant
# 224 | POSITIVE   | POSITIVE        | The wagyu beef was worth every penny. Melt-in
# 225 | NEGATIVE   | NEGATIVE        | The avocado on the toast was brown and clearl
# 226 | NEGATIVE   | NEGATIVE        | Brilliant brunch spot on weekdays. Avoid week
# 227 | NEGATIVE   | NEGATIVE        | They seated us right next to the kitchen door
# 228 | NEGATIVE   | NEGATIVE        | The sushi rice was warm and mushy. A fundamen
# 229 | POSITIVE   | POSITIVE        | We drove an hour to get here based on a frien
# 230 | POSITIVE   | POSITIVE        | They catered our wedding and every single gue
# 231 | POSITIVE   | POSITIVE        | The sourdough bread they bring to the table b
# 232 | POSITIVE   | POSITIVE        | Five stars. The lamb shank fell off the bone
# 233 | POSITIVE   | POSITIVE        | We've been coming here every Friday for three
# 234 | NEGATIVE   | NEGATIVE        | The fish smelled off. I didn't eat it and I'm
# 235 | NEGATIVE   | NEGATIVE        | Our server was on their phone for most of our
# 236 | POSITIVE   | POSITIVE        | We ordered the sharing platter for two and it
# 237 | NEGATIVE   | NEGATIVE        | We could hear the staff arguing in the kitche
# 238 | NEGATIVE   | NEGATIVE        | The first time we came it was fantastic. This
# 239 | NEGATIVE   | NEGATIVE        | The takeaway is great but eating in is a letd
# 240 | NEGATIVE   | NEGATIVE        | They overbooked and tried to seat us at a tin
# 241 | NEGATIVE   | NEGATIVE        | I've eaten at Michelin-starred restaurants th
# 242 | NEUTRAL    | NEUTRAL         | A perfectly adequate restaurant. Not somewher
# 243 | POSITIVE   | POSITIVE        | The pho was aromatic and warming — exactly wh
# 244 | POSITIVE   | POSITIVE        | Fast, fresh, affordable. This place is my go-
# 245 | POSITIVE   | POSITIVE        | My partner is vegan and I eat everything — we
# 246 | POSITIVE   | POSITIVE        | The lobster bisque was silky smooth and packe
# 247 | NEUTRAL    | NEUTRAL         | Middle of the road. The burger was edible, th
# 248 | POSITIVE   | POSITIVE        | The brunch here is unreal. Eggs benedict with
# 249 | POSITIVE   | POSITIVE        | Everything we ordered was beautifully present
# 250 | NEGATIVE   | NEGATIVE        | We pointed out a fly in the restaurant and we
#
# Done! Classified 250 reviews in 31.6s
# Average: 0.13s per review

# %% [markdown]
# ---
# ## 6: View the summary
#
# Let's see how the model did overall. We use Python's `Counter` to tally up how many reviews fell into each category.

# %%
from collections import Counter

counts = Counter(r["label"] for r in results)

print("=== Classification Summary ===")
for label in ["POSITIVE", "NEGATIVE", "NEUTRAL", "UNKNOWN"]:
    if counts[label] > 0:
        bar = "█" * counts[label]  # Simple bar chart
        print(f"  {label:<10} {bar} ({counts[label]})")

# Flag any reviews the model couldn't classify cleanly
if counts["UNKNOWN"] > 0:
    print(f"\n⚠️  {counts['UNKNOWN']} reviews couldn't be classified cleanly.")
    print("   This can happen with small models — here's what it actually said:")
    for r in results:
        if r["label"] == "UNKNOWN":
            print(f"     [{r['id']}] Model said: '{r['raw']}'")
# Out:
# === Classification Summary ===
#   POSITIVE   ██████████████████████████████████████████████████████████████████████████████████████████████████ (98)
#   NEGATIVE   ████████████████████████████████████████████████████████████████████████████████████████████████████████ (104)
#   NEUTRAL    ████████████████████████████████████████████████ (48)

# %% [markdown]
# ---
# ## 12: Discussion Points
#
# **How well did it do?**
# - Look at the results above. Were there any obvious mistakes?
# - Which reviews were hardest for the model? Why?
#
# **The role of the prompt:**
# - We gave the model a system message ("You are a sentiment classifier") and a user message (the review). Why split it this way?
# - What might happen if we just said "What do you think of this review?" instead?
#
# **Size matters:**
# - This model has 0.5 billion parameters. GPT-4 has over 1 trillion. What's the trade-off?
# - Could you use a model this small in production? When would you need something bigger?
#
# **Local vs. cloud:**
# - What are the advantages of running a model locally instead of calling an API like ChatGPT?
# - What are the disadvantages?
#
# ---
# ## 13: Challenges to try
#
# 1. **Few-shot prompting:** Add examples to the system message, e.g. *'Example: "Great product!" → POSITIVE'*. Does accuracy improve?
# 2. **Five categories:** Change the prompt to classify as very positive / positive / neutral / negative / very negative. Can the model handle it?
# 3. **Swap the model:** Try `HuggingFaceTB/SmolLM2-360M-Instruct` (even smaller). How does it compare?
# 4. **Your own reviews:** Replace the commented-out reviews list with reviews that you've written, or reviews that you've found on a real online shop. Do the results surprise you?
